# %%
import pandas as pd
import numpy as np

print("¡El ecosistema de StreamRiver está activo!")
print(f"Versión de Pandas instalada: {pd.__version__}")

# Simulación de una matriz de datos (Estructura básica)
data = np.array([['Pelicula', 'Vistas'], ['Matrix', 5000000]])
print("Prueba de matriz numpy exitosa.")
# Out:
# ¡El ecosistema de StreamRiver está activo!
# Versión de Pandas instalada: 2.3.3
# Prueba de matriz numpy exitosa.

# %%
import sys
sys.executable
# Out:
# '/opt/anaconda3/envs/curso_bigdata/bin/python'
